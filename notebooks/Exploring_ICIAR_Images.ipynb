# %%
import tensorflow as tf
import numpy as np
import os

from os import listdir
from os.path import isfile, join

from PIL import Image

from skimage import img_as_ubyte, img_as_float
from skimage.io import imread, imsave

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
#Utility functions

def show_images(images):
    n = int(np.ceil(np.sqrt(len(images))))
    fig = plt.figure(figsize=(n, n))
    gs = gridspec.GridSpec(n, n)
    gs.update(wspace=0.05, hspace=0.05)

    for i, img in enumerate(images):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(img)
        
def read_img_patches(path,name):
    patches = []
    for i in range(764):
        img = Image.open(path+'Normal/normal_patches/'+name+'-'+str(i)+'.png')
        patches.append(np.array(img))
    return patches

def read_full_img(path, n = 100):
    image_names = [f for f in listdir(path) if isfile(join(path, f))]
    image_names.remove('Thumbs.db')
    image_names.sort()
    images = []
    for name in image_names[0:n]:
        img = imread(path+name)
        img = img_as_float(img)
        images.append(img)
    return images

# %%
#Global
path = '../../work/slides/ICIAR2018_BACH_Challenge/Photos/'

# %%
#Normal images
normal_images = read_full_img(path+'Normal/', n=10)
print(len(normal_images))
# Out:
# 10

# %%
plt.imshow(normal_images[3])

# %%
#Read patches from one image
name = 'n006'
patches = read_img_patches(path,name)
len(patches)
# Out:
# 764

# %%
show_images(patches[300:350])

# %%
#Read samples!
samples_path = '../../work/slides/dcgan-completion.tensorflow/samples/'
samples_names = [f for f in listdir(samples_path) if isfile(join(samples_path, f))]
samples_names.sort()

# %%
samples = []
for name in samples_names:
    img = Image.open(samples_path+name)
    samples.append(np.array(img))
print(len(samples))
# Out:
# 600

# %%
plt.imshow(samples[-6])

# %%
#make gif
def make_gif(images, fname, duration=15, true_image=True):
  import moviepy.editor as mpy

  def make_frame(t):
    try:
      x = images[int(len(images)/duration*t)]
    except:
      x = images[-1]

    if true_image:
      return x.astype(np.uint8)
    else:
      return ((x+1)/2*255).astype(np.uint8)

  clip = mpy.VideoClip(make_frame, duration=duration)
  clip.write_gif(fname, fps = len(images) / duration)

# %%
make_gif(samples, samples_path+'gifs/gif_15_epoch1.gif')
# Out:
# [MoviePy] Building file ../../work/slides/dcgan-completion.tensorflow/samples/gifs/gif_15_epoch1.gif with imageio
#  99%|█████████▉| 105/106 [00:26<00:00,  4.11it/s]

# %%
from IPython.display import Image
from IPython.display import display
#display(Image(url=samples_path+'gifs/gif_15_epoch1.gif'))

# %%
#Invasive images
invasive_images = read_full_img(path+'Invasive/', n = 10)
print(len(invasive_images))
# Out:
# 10

# %%
plt.imshow(invasive_images[9])

# %%
#Invasive images
insitu_images = read_full_img(path+'InSitu/', n = 10)
print(len(insitu_images))
# Out:
# 10

# %%
plt.imshow(insitu_images[5])
